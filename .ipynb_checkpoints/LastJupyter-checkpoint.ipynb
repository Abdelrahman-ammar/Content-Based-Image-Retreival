# %%
import numpy as np
import tensorflow as tf
from keras.applications.resnet import ResNet50
from keras.applications.resnet import preprocess_input
from tensorflow.keras.preprocessing import image
import os
from numpy.linalg import norm
from tensorflow.keras import Sequential,layers

# %%
ResnetModel = ResNet50(weights="imagenet",include_top=False,input_shape=(224,224,3))

# %%
model = Sequential([
    ResnetModel,
    layers.GlobalAveragePooling2D(), #2048
])

# %%
file_paths = tf.data.Dataset.list_files("Flowers/*",shuffle=False)
for image in file_paths.take(5):
    print(image)
# Out:
# tf.Tensor(b'Flowers\\Flower.jpg', shape=(), dtype=string)
# tf.Tensor(b'Flowers\\Flower2.jpg', shape=(), dtype=string)
# tf.Tensor(b'Flowers\\bougainvillea_00002.jpg', shape=(), dtype=string)
# tf.Tensor(b'Flowers\\bougainvillea_00003.jpg', shape=(), dtype=string)
# tf.Tensor(b'Flowers\\bougainvillea_00004.jpg', shape=(), dtype=string)

# %%
def ResnetPreprocess(filepath):
    
    image = tf.io.read_file(filepath)
    
    image = tf.image.decode_jpeg(image, channels=3)
    
    image = tf.image.resize(image,(224,224))
    image = preprocess_input(image)
    
    return image

images_ds = file_paths.map(ResnetPreprocess)
images_ds = images_ds.batch(32)

# %%
features = model.predict(images_ds)
# Out:
# 13/13 [==============================] - 19s 1s/step

# %%
features.shape
# Out:
# (408, 2048)

# %%
def get_label(filepath):
    return tf.strings.split(filepath, os.path.sep)[-1]

labels_ds = file_paths.map(get_label)

# %%
labels_ds
# Out:
# <_MapDataset element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %%
labels = []
for label in labels_ds:
    labels.append(label.numpy().decode('utf-8'))
labels
# Out:
# ['Flower.jpg',
#  'Flower2.jpg',
#  'bougainvillea_00002.jpg',
#  'bougainvillea_00003.jpg',
#  'bougainvillea_00004.jpg',
#  'bougainvillea_00005.jpg',
#  'bougainvillea_00006.jpg',
#  'bougainvillea_00007.jpg',
#  'bougainvillea_00008.jpg',
#  'bougainvillea_00009.jpg',
#  'bougainvillea_00010.jpg',
#  'bougainvillea_00012.jpg',
#  'bougainvillea_00013.jpg',
#  'bougainvillea_00014.jpg',
#  'bougainvillea_00015.jpg',
#  'bougainvillea_00016.jpg',
#  'bougainvillea_00017.jpg',
#  'bougainvillea_00018.jpg',
#  'bougainvillea_00019.jpg',
#  'bougainvillea_00020.jpg',
#  'bougainvillea_00021.jpg',
#  'bougainvillea_00022.jpg',
#  'bougainvillea_00023.jpg',
#  'bougainvillea_00024.jpg',
#  'bougainvillea_00025.jpg',
#  'bougainvillea_00026.jpg',
#  'bougainvillea_00027.jpg',
#  'bougainvillea_00028.jpg',
#  'bougainvillea_00029.jpg',
#  'bougainvillea_00030.jpg',
#  'bougainvillea_00031.jpg',
#  'bougainvillea_00032.jpg',
#  'bougainvillea_00033.jpg',
#  'bougainvillea_00034.jpg',
#  'bougainvillea_00035.jpg',
#  'bougainvillea_00036.jpg',
#  'bougainvillea_00037.jpg',
#  'bougainvillea_00038.jpg',
#  'bougainvillea_00039.jpg',
#  'bougainvillea_00040.jpg',
#  'bougainvillea_00041.jpg',
#  'bougainvillea_00042.jpg',
#  'bougainvillea_00043.jpg',
#  'bougainvillea_00044.jpg',
#  'bougainvillea_00045.jpg',
#  'bougainvillea_00046.jpg',
#  'bougainvillea_00047.jpg',
#  'bougainvillea_00048.jpg',
#  'bougainvillea_00049.jpg',
#  'bougainvillea_00050.jpg',
#  'bougainvillea_00051.jpg',
#  'bougainvillea_00052.jpg',
#  'bougainvillea_00053.jpg',
#  'bougainvillea_00054.jpg',
#  'bougainvillea_00055.jpg',
#  'bougainvillea_00056.jpg',
#  'bougainvillea_00057.jpg',
#  'bougainvillea_00058.jpg',
#  'bougainvillea_00059.jpg',
#  'bougainvillea_00060.jpg',
#  'bougainvillea_00061.jpg',
#  'bougainvillea_00063.jpg',
#  'bougainvillea_00064.jpg',
#  'bougainvillea_00066.jpg',
#  'bougainvillea_00067.jpg',
#  'bougainvillea_00068.jpg',
#  'bougainvillea_00069.jpg',
#  'bougainvillea_00070.jpg',
#  'bougainvillea_00072.jpg',
#  'bougainvillea_00073.jpg',
#  'bougainvillea_00074.jpg',
#  'bougainvillea_00075.jpg',
#  'bougainvillea_00076.jpg',
#  'bougainvillea_00077.jpg',
#  'bougainvillea_00078.jpg',
#  'bougainvillea_00079.jpg',
#  'daisies_00002.jpg',
#  'daisies_00003.jpg',
#  'daisies_00004.jpg',
#  'daisies_00005.jpg',
#  'daisies_00006.jpg',
#  'daisies_00007.jpg',
#  'daisies_00008.jpg',
#  'daisies_00009.jpg',
#  'daisies_00010.jpg',
#  'daisies_00011.jpg',
#  'daisies_00012.jpg',
#  'daisies_00013.jpg',
#  'daisies_00014.jpg',
#  'daisies_00015.jpg',
#  'daisies_00016.jpg',
#  'daisies_00017.jpg',
#  'daisies_00018.jpg',
#  'daisies_00019.jpg',
#  'daisies_00020.jpg',
#  'daisies_00021.jpg',
#  'daisies_00022.jpg',
#  'daisies_00023.jpg',
#  'daisies_00024.jpg',
#  'daisies_00025.jpg',
#  'daisies_00026.jpg',
#  'daisies_00027.jpg',
#  'daisies_00028.jpg',
#  'daisies_00029.jpg',
#  'daisies_00030.jpg',
#  'daisies_00031.jpg',
#  'daisies_00032.jpg',
#  'daisies_00033.jpg',
#  'daisies_00034.jpg',
#  'daisies_00035.jpg',
#  'daisies_00036.jpg',
#  'daisies_00037.jpg',
#  'daisies_00038.jpg',
#  'daisies_00039.jpg',
#  'daisies_00040.jpg',
#  'daisies_00041.jpg',
#  'daisies_00043.jpg',
#  'daisies_00044.jpg',
#  'daisies_00046.jpg',
#  'daisies_00047.jpg',
#  'daisies_00048.jpg',
#  'daisies_00049.jpg',
#  'daisies_00050.jpg',
#  'daisies_00051.jpg',
#  'daisies_00052.jpg',
#  'daisies_00053.jpg',
#  'daisies_00054.jpg',
#  'daisies_00055.jpg',
#  'daisies_00056.jpg',
#  'daisies_00057.jpg',
#  'daisies_00058.jpg',
#  'daisies_00059.jpg',
#  'daisies_00060.jpg',
#  'daisies_00061.jpg',
#  'daisies_00062.jpg',
#  'daisies_00063.jpg',
#  'daisies_00064.jpg',
#  'daisies_00065.jpg',
#  'daisies_00066.jpg',
#  'daisies_00068.jpg',
#  'daisies_00070.jpg',
#  'daisies_00071.jpg',
#  'daisies_00072.jpg',
#  'daisies_00073.jpg',
#  'daisies_00074.jpg',
#  'daisies_00075.jpg',
#  'daisies_00076.jpg',
#  'daisies_00077.jpg',
#  'daisies_00078.jpg',
#  'daisies_00079.jpg',
#  'daisies_00080.jpg',
#  'daisies_00081.jpg',
#  'daisies_00082.jpg',
#  'daisies_00083.jpg',
#  'daisies_00084.jpg',
#  'daisies_00085.jpg',
#  'daisies_00086.jpg',
#  'daisies_00087.jpg',
#  'daisies_00088.jpg',
#  'garden_roses_00003.jpg',
#  'garden_roses_00005.jpg',
#  'garden_roses_00006.jpg',
#  'garden_roses_00007.jpg',
#  'garden_roses_00008.jpg',
#  'garden_roses_00009.jpg',
#  'garden_roses_00011.jpg',
#  'garden_roses_00012.jpg',
#  'garden_roses_00013.jpg',
#  'garden_roses_00014.jpg',
#  'garden_roses_00015.jpg',
#  'garden_roses_00016.jpg',
#  'garden_roses_00017.jpg',
#  'garden_roses_00018.jpg',
#  'garden_roses_00019.jpg',
#  'garden_roses_00020.jpg',
#  'garden_roses_00022.jpg',
#  'garden_roses_00023.jpg',
#  'garden_roses_00024.jpg',
#  'garden_roses_00025.jpg',
#  'garden_roses_00026.jpg',
#  'garden_roses_00027.jpg',
#  'garden_roses_00028.jpg',
#  'garden_roses_00030.jpg',
#  'garden_roses_00031.jpg',
#  'garden_roses_00032.jpg',
#  'garden_roses_00033.jpg',
#  'garden_roses_00034.jpg',
#  'garden_roses_00035.jpg',
#  'garden_roses_00036.jpg',
#  'garden_roses_00037.jpg',
#  'garden_roses_00038.jpg',
#  'garden_roses_00039.jpg',
#  'garden_roses_00040.jpg',
#  'garden_roses_00041.jpg',
#  'garden_roses_00042.jpg',
#  'garden_roses_00043.jpg',
#  'garden_roses_00045.jpg',
#  'garden_roses_00046.jpg',
#  'garden_roses_00047.jpg',
#  'garden_roses_00049.jpg',
#  'garden_roses_00050.jpg',
#  'garden_roses_00051.jpg',
#  'garden_roses_00052.jpg',
#  'garden_roses_00053.jpg',
#  'garden_roses_00054.jpg',
#  'garden_roses_00055.jpg',
#  'garden_roses_00057.jpg',
#  'garden_roses_00058.jpg',
#  'garden_roses_00060.jpg',
#  'garden_roses_00061.jpg',
#  'garden_roses_00062.jpg',
#  'garden_roses_00063.jpg',
#  'garden_roses_00065.jpg',
#  'garden_roses_00066.jpg',
#  'garden_roses_00067.jpg',
#  'garden_roses_00068.jpg',
#  'garden_roses_00069.jpg',
#  'garden_roses_00070.jpg',
#  'garden_roses_00071.jpg',
#  'garden_roses_00072.jpg',
#  'garden_roses_00073.jpg',
#  'garden_roses_00074.jpg',
#  'garden_roses_00075.jpg',
#  'garden_roses_00076.jpg',
#  'garden_roses_00077.jpg',
#  'garden_roses_00078.jpg',
#  'garden_roses_00079.jpg',
#  'garden_roses_00080.jpg',
#  'garden_roses_00083.jpg',
#  'garden_roses_00084.jpg',
#  'garden_roses_00085.jpg',
#  'garden_roses_00086.jpg',
#  'garden_roses_00087.jpg',
#  'gardenias_00002.jpg',
#  'gardenias_00003.jpg',
#  'gardenias_00004.jpg',
#  'gardenias_00005.jpg',
#  'gardenias_00006.jpg',
#  'gardenias_00007.jpg',
#  'gardenias_00008.jpg',
#  'gardenias_00009.jpg',
#  'gardenias_00010.jpg',
#  'gardenias_00011.jpg',
#  'gardenias_00012.jpg',
#  'gardenias_00013.jpg',
#  'gardenias_00014.jpg',
#  'gardenias_00015.jpg',
#  'gardenias_00016.jpg',
#  'gardenias_00018.jpg',
#  'gardenias_00019.jpg',
#  'gardenias_00020.jpg',
#  'gardenias_00021.jpg',
#  'gardenias_00022.jpg',
#  'gardenias_00023.jpg',
#  'gardenias_00024.jpg',
#  'gardenias_00025.jpg',
#  'gardenias_00026.jpg',
#  'gardenias_00027.jpg',
#  'gardenias_00028.jpg',
#  'gardenias_00029.jpg',
#  'gardenias_00030.jpg',
#  'gardenias_00031.jpg',
#  'gardenias_00032.jpg',
#  'gardenias_00034.jpg',
#  'gardenias_00035.jpg',
#  'gardenias_00036.jpg',
#  'gardenias_00037.jpg',
#  'gardenias_00038.jpg',
#  'gardenias_00039.jpg',
#  'gardenias_00040.jpg',
#  'gardenias_00041.jpg',
#  'gardenias_00042.jpg',
#  'gardenias_00043.jpg',
#  'gardenias_00045.jpg',
#  'gardenias_00046.jpg',
#  'gardenias_00047.jpg',
#  'gardenias_00048.jpg',
#  'gardenias_00049.jpg',
#  'gardenias_00051.jpg',
#  'gardenias_00052.jpg',
#  'gardenias_00054.jpg',
#  'gardenias_00055.jpg',
#  'gardenias_00056.jpg',
#  'gardenias_00057.jpg',
#  'gardenias_00058.jpg',
#  'gardenias_00059.jpg',
#  'gardenias_00060.jpg',
#  'gardenias_00063.jpg',
#  'gardenias_00064.jpg',
#  'gardenias_00065.jpg',
#  'gardenias_00066.jpg',
#  'gardenias_00067.jpg',
#  'gardenias_00068.jpg',
#  'gardenias_00069.jpg',
#  'gardenias_00070.jpg',
#  'gardenias_00071.jpg',
#  'gardenias_00072.jpg',
#  'gardenias_00073.jpg',
#  'gardenias_00075.jpg',
#  'gardenias_00076.jpg',
#  'gardenias_00077.jpg',
#  'gardenias_00078.jpg',
#  'gardenias_00079.jpg',
#  'gardenias_00080.jpg',
#  'gardenias_00081.jpg',
#  'gardenias_00082.jpg',
#  'gardenias_00083.jpg',
#  'gardenias_00084.jpg',
#  'gardenias_00085.jpg',
#  'gardenias_00086.jpg',
#  'hibiscus_00002.jpg',
#  'hibiscus_00003.jpg',
#  'hibiscus_00004.jpg',
#  'hibiscus_00005.jpg',
#  'hibiscus_00006.jpg',
#  'hibiscus_00007.jpg',
#  'hibiscus_00009.jpg',
#  'hibiscus_00010.jpg',
#  'hibiscus_00011.jpg',
#  'hibiscus_00012.jpg',
#  'hibiscus_00014.jpg',
#  'hibiscus_00015.jpg',
#  'hibiscus_00016.jpg',
#  'hibiscus_00018.jpg',
#  'hibiscus_00019.jpg',
#  'hibiscus_00021.jpg',
#  'hibiscus_00022.jpg',
#  'hibiscus_00025.jpg',
#  'hibiscus_00027.jpg',
#  'hibiscus_00028.jpg',
#  'hibiscus_00029.jpg',
#  'hibiscus_00030.jpg',
#  'hibiscus_00031.jpg',
#  'hibiscus_00032.jpg',
#  'hibiscus_00034.jpg',
#  'hibiscus_00036.jpg',
#  'hibiscus_00037.jpg',
#  'hibiscus_00038.jpg',
#  'hibiscus_00039.jpg',
#  'hibiscus_00040.jpg',
#  'hibiscus_00041.jpg',
#  'hibiscus_00042.jpg',
#  'hibiscus_00043.jpg',
#  'hibiscus_00044.jpg',
#  'hibiscus_00045.jpg',
#  'hibiscus_00046.jpg',
#  'hibiscus_00047.jpg',
#  'hibiscus_00048.jpg',
#  'hibiscus_00049.jpg',
#  'hibiscus_00050.jpg',
#  'hibiscus_00051.jpg',
#  'hibiscus_00052.jpg',
#  'hibiscus_00053.jpg',
#  'hibiscus_00054.jpg',
#  'hibiscus_00055.jpg',
#  'hibiscus_00056.jpg',
#  'hibiscus_00057.jpg',
#  'hibiscus_00058.jpg',
#  'hibiscus_00059.jpg',
#  'hibiscus_00060.jpg',
#  'hibiscus_00061.jpg',
#  'hibiscus_00062.jpg',
#  'hibiscus_00063.jpg',
#  'hibiscus_00064.jpg',
#  'hibiscus_00065.jpg',
#  'hibiscus_00066.jpg',
#  'hibiscus_00067.jpg',
#  'hibiscus_00068.jpg',
#  'hibiscus_00069.jpg',
#  'hibiscus_00070.jpg',
#  'hibiscus_00071.jpg',
#  'hibiscus_00072.jpg',
#  'hibiscus_00073.jpg',
#  'hibiscus_00074.jpg',
#  'hibiscus_00075.jpg',
#  'hibiscus_00076.jpg',
#  'hibiscus_00077.jpg',
#  'hibiscus_00078.jpg',
#  'hibiscus_00079.jpg',
#  'hibiscus_00080.jpg',
#  'hibiscus_00081.jpg',
#  'hibiscus_00082.jpg',
#  'hibiscus_00083.jpg',
#  'hibiscus_00084.jpg',
#  'hydrangeas_00002.jpg',
#  'hydrangeas_00003.jpg',
#  'hydrangeas_00004.jpg',
#  'hydrangeas_00005.jpg',
#  'hydrangeas_00006.jpg',
#  'hydrangeas_00007.jpg',
#  'hydrangeas_00008.jpg',
#  'hydrangeas_00009.jpg',
#  'hydrangeas_00010.jpg',
#  'hydrangeas_00012.jpg',
#  'hydrangeas_00013.jpg',
#  'hydrangeas_00014.jpg',
#  'hydrangeas_00015.jpg',
#  'hydrangeas_00016.jpg',
#  'hydrangeas_00017.jpg',
#  'hydrangeas_00018.jpg',
#  'hydrangeas_00019.jpg',
#  'hydrangeas_00020.jpg',
#  'hydrangeas_00021.jpg',
#  'hydrangeas_00022.jpg',
#  'hydrangeas_00024.jpg',
#  'hydrangeas_00026.jpg',
#  'hydrangeas_00027.jpg',
#  'hydrangeas_00028.jpg']

# %%
labels[0]
# Out:
# 'Flower.jpg'

# %%
len(labels)
# Out:
# 408

# %%
def hash_func(embedding, random_vectors):
    embedding = np.array(embedding)
    
    bools = np.dot(embedding, random_vectors.T) > 0

    return [bool2int(bool_vec) for bool_vec in bools]


def bool2int(x):
    y = np.sum(2**np.where(x)[0])
    return y

# %%
def create_projections(dimensions,size,seed):
    np.random.seed(seed)
    return np.random.normal(size=(size,dimensions))

# %%
def create_table(dimensions,hash_size,vectors,labels,seed):
    table = {}
    random_projections = create_projections(dimensions,hash_size,seed)
    hashes = hash_func(vectors,random_projections)
    for i, hash_code in enumerate(hashes):
        if hash_code in table:
            table[hash_code].append(labels[i])
        else:
            table[hash_code] = [labels[i]]
    
    return table

# %%
labels[0]
# Out:
# 'Flower.jpg'

# %%
def Build_tables(numtables,dimensions,hash_size,vectors,labels):
    tables = []
    for i in range(numtables):
        tables.append(create_table(dimensions,hash_size,vectors,labels,seed=i))
    return tables

# %%
tables = Build_tables(10,2048,8,features,labels)

# %%
tables[1]
# Out:
# {189: ['Flower.jpg',
#   'bougainvillea_00006.jpg',
#   'bougainvillea_00009.jpg',
#   'bougainvillea_00018.jpg',
#   'bougainvillea_00021.jpg',
#   'bougainvillea_00027.jpg',
#   'bougainvillea_00041.jpg',
#   'bougainvillea_00054.jpg',
#   'bougainvillea_00057.jpg',
#   'bougainvillea_00058.jpg',
#   'bougainvillea_00067.jpg',
#   'bougainvillea_00068.jpg',
#   'bougainvillea_00070.jpg',
#   'daisies_00006.jpg',
#   'daisies_00013.jpg',
#   'daisies_00018.jpg',
#   'daisies_00020.jpg',
#   'daisies_00021.jpg',
#   'daisies_00029.jpg',
#   'daisies_00031.jpg',
#   'daisies_00032.jpg',
#   'daisies_00037.jpg',
#   'daisies_00039.jpg',
#   'daisies_00040.jpg',
#   'daisies_00047.jpg',
#   'daisies_00049.jpg',
#   'daisies_00052.jpg',
#   'daisies_00058.jpg',
#   'daisies_00060.jpg',
#   'daisies_00066.jpg',
#   'daisies_00068.jpg',
#   'daisies_00070.jpg',
#   'daisies_00072.jpg',
#   'daisies_00076.jpg',
#   'daisies_00077.jpg',
#   'daisies_00080.jpg',
#   'daisies_00082.jpg',
#   'daisies_00085.jpg',
#   'garden_roses_00013.jpg',
#   'garden_roses_00034.jpg',
#   'garden_roses_00039.jpg',
#   'garden_roses_00041.jpg',
#   'garden_roses_00046.jpg',
#   'garden_roses_00049.jpg',
#   'garden_roses_00053.jpg',
#   'garden_roses_00060.jpg',
#   'garden_roses_00075.jpg',
#   'garden_roses_00079.jpg',
#   'gardenias_00002.jpg',
#   'gardenias_00003.jpg',
#   'gardenias_00007.jpg',
#   'gardenias_00009.jpg',
#   'gardenias_00013.jpg',
#   'gardenias_00020.jpg',
#   'gardenias_00021.jpg',
#   'gardenias_00022.jpg',
#   'gardenias_00024.jpg',
#   'gardenias_00025.jpg',
#   'gardenias_00028.jpg',
#   'gardenias_00031.jpg',
#   'gardenias_00035.jpg',
#   'gardenias_00042.jpg',
#   'gardenias_00048.jpg',
#   'gardenias_00055.jpg',
#   'gardenias_00059.jpg',
#   'gardenias_00060.jpg',
#   'gardenias_00064.jpg',
#   'gardenias_00066.jpg',
#   'gardenias_00073.jpg',
#   'gardenias_00075.jpg',
#   'gardenias_00076.jpg',
#   'gardenias_00077.jpg',
#   'gardenias_00078.jpg',
#   'gardenias_00080.jpg',
#   'hibiscus_00002.jpg',
#   'hibiscus_00003.jpg',
#   'hibiscus_00005.jpg',
#   'hibiscus_00006.jpg',
#   'hibiscus_00009.jpg',
#   'hibiscus_00014.jpg',
#   'hibiscus_00018.jpg',
#   'hibiscus_00037.jpg',
#   'hibiscus_00038.jpg',
#   'hibiscus_00039.jpg',
#   'hibiscus_00040.jpg',
#   'hibiscus_00042.jpg',
#   'hibiscus_00043.jpg',
#   'hibiscus_00046.jpg',
#   'hibiscus_00047.jpg',
#   'hibiscus_00048.jpg',
#   'hibiscus_00049.jpg',
#   'hibiscus_00051.jpg',
#   'hibiscus_00052.jpg',
#   'hibiscus_00057.jpg',
#   'hibiscus_00061.jpg',
#   'hibiscus_00063.jpg',
#   'hibiscus_00065.jpg',
#   'hibiscus_00066.jpg',
#   'hibiscus_00067.jpg',
#   'hibiscus_00068.jpg',
#   'hibiscus_00069.jpg',
#   'hibiscus_00072.jpg',
#   'hibiscus_00073.jpg',
#   'hibiscus_00078.jpg',
#   'hibiscus_00081.jpg',
#   'hibiscus_00082.jpg',
#   'hibiscus_00084.jpg',
#   'hydrangeas_00004.jpg',
#   'hydrangeas_00005.jpg',
#   'hydrangeas_00007.jpg',
#   'hydrangeas_00014.jpg',
#   'hydrangeas_00015.jpg',
#   'hydrangeas_00020.jpg',
#   'hydrangeas_00021.jpg',
#   'hydrangeas_00022.jpg',
#   'hydrangeas_00028.jpg'],
#  141: ['Flower2.jpg',
#   'bougainvillea_00017.jpg',
#   'daisies_00087.jpg',
#   'garden_roses_00055.jpg',
#   'gardenias_00015.jpg'],
#  45: ['bougainvillea_00002.jpg',
#   'bougainvillea_00022.jpg',
#   'bougainvillea_00025.jpg',
#   'bougainvillea_00038.jpg',
#   'bougainvillea_00051.jpg',
#   'bougainvillea_00066.jpg',
#   'bougainvillea_00072.jpg',
#   'hydrangeas_00016.jpg',
#   'hydrangeas_00019.jpg'],
#  173: ['bougainvillea_00003.jpg',
#   'bougainvillea_00004.jpg',
#   'bougainvillea_00007.jpg',
#   'bougainvillea_00010.jpg',
#   'bougainvillea_00015.jpg',
#   'bougainvillea_00016.jpg',
#   'bougainvillea_00032.jpg',
#   'bougainvillea_00033.jpg',
#   'bougainvillea_00034.jpg',
#   'bougainvillea_00036.jpg',
#   'bougainvillea_00040.jpg',
#   'bougainvillea_00045.jpg',
#   'bougainvillea_00046.jpg',
#   'bougainvillea_00047.jpg',
#   'bougainvillea_00049.jpg',
#   'bougainvillea_00053.jpg',
#   'bougainvillea_00069.jpg',
#   'bougainvillea_00073.jpg',
#   'bougainvillea_00075.jpg',
#   'bougainvillea_00077.jpg',
#   'bougainvillea_00079.jpg',
#   'daisies_00011.jpg',
#   'daisies_00055.jpg',
#   'garden_roses_00054.jpg',
#   'hibiscus_00007.jpg',
#   'hibiscus_00015.jpg',
#   'hibiscus_00022.jpg',
#   'hibiscus_00027.jpg',
#   'hibiscus_00054.jpg',
#   'hibiscus_00056.jpg',
#   'hibiscus_00074.jpg',
#   'hydrangeas_00006.jpg',
#   'hydrangeas_00010.jpg',
#   'hydrangeas_00026.jpg'],
#  61: ['bougainvillea_00005.jpg',
#   'bougainvillea_00019.jpg',
#   'bougainvillea_00020.jpg',
#   'bougainvillea_00024.jpg',
#   'bougainvillea_00029.jpg',
#   'bougainvillea_00035.jpg',
#   'bougainvillea_00042.jpg',
#   'bougainvillea_00048.jpg',
#   'bougainvillea_00055.jpg',
#   'bougainvillea_00064.jpg',
#   'bougainvillea_00074.jpg',
#   'garden_roses_00005.jpg',
#   'garden_roses_00006.jpg',
#   'garden_roses_00007.jpg',
#   'garden_roses_00016.jpg',
#   'garden_roses_00018.jpg',
#   'garden_roses_00020.jpg',
#   'garden_roses_00022.jpg',
#   'garden_roses_00023.jpg',
#   'garden_roses_00025.jpg',
#   'garden_roses_00028.jpg',
#   'garden_roses_00031.jpg',
#   'garden_roses_00033.jpg',
#   'garden_roses_00036.jpg',
#   'garden_roses_00043.jpg',
#   'garden_roses_00061.jpg',
#   'garden_roses_00063.jpg',
#   'garden_roses_00066.jpg',
#   'garden_roses_00068.jpg',
#   'garden_roses_00069.jpg',
#   'garden_roses_00070.jpg',
#   'garden_roses_00074.jpg',
#   'garden_roses_00076.jpg',
#   'gardenias_00032.jpg',
#   'gardenias_00040.jpg',
#   'gardenias_00046.jpg',
#   'gardenias_00067.jpg',
#   'gardenias_00079.jpg',
#   'gardenias_00084.jpg',
#   'hibiscus_00029.jpg',
#   'hydrangeas_00003.jpg',
#   'hydrangeas_00009.jpg',
#   'hydrangeas_00013.jpg'],
#  253: ['bougainvillea_00008.jpg',
#   'garden_roses_00011.jpg',
#   'hibiscus_00080.jpg'],
#  37: ['bougainvillea_00012.jpg', 'bougainvillea_00059.jpg'],
#  53: ['bougainvillea_00013.jpg',
#   'bougainvillea_00026.jpg',
#   'garden_roses_00009.jpg',
#   'garden_roses_00032.jpg',
#   'garden_roses_00035.jpg',
#   'garden_roses_00045.jpg',
#   'hydrangeas_00017.jpg'],
#  181: ['bougainvillea_00014.jpg',
#   'bougainvillea_00076.jpg',
#   'daisies_00003.jpg',
#   'daisies_00007.jpg',
#   'daisies_00009.jpg',
#   'daisies_00010.jpg',
#   'daisies_00015.jpg',
#   'daisies_00016.jpg',
#   'daisies_00017.jpg',
#   'daisies_00019.jpg',
#   'daisies_00024.jpg',
#   'daisies_00025.jpg',
#   'daisies_00026.jpg',
#   'daisies_00027.jpg',
#   'daisies_00033.jpg',
#   'daisies_00041.jpg',
#   'daisies_00043.jpg',
#   'daisies_00044.jpg',
#   'daisies_00046.jpg',
#   'daisies_00048.jpg',
#   'daisies_00054.jpg',
#   'daisies_00073.jpg',
#   'daisies_00074.jpg',
#   'daisies_00078.jpg',
#   'garden_roses_00047.jpg',
#   'garden_roses_00051.jpg',
#   'garden_roses_00083.jpg',
#   'gardenias_00071.jpg',
#   'hydrangeas_00024.jpg'],
#  21: ['bougainvillea_00023.jpg',
#   'bougainvillea_00028.jpg',
#   'garden_roses_00037.jpg'],
#  60: ['bougainvillea_00030.jpg',
#   'bougainvillea_00043.jpg',
#   'garden_roses_00026.jpg',
#   'garden_roses_00030.jpg',
#   'garden_roses_00072.jpg',
#   'garden_roses_00073.jpg'],
#  157: ['bougainvillea_00031.jpg',
#   'bougainvillea_00044.jpg',
#   'bougainvillea_00060.jpg',
#   'bougainvillea_00078.jpg',
#   'daisies_00014.jpg',
#   'daisies_00050.jpg',
#   'daisies_00083.jpg',
#   'gardenias_00004.jpg',
#   'gardenias_00011.jpg',
#   'gardenias_00023.jpg',
#   'gardenias_00026.jpg',
#   'gardenias_00036.jpg',
#   'gardenias_00054.jpg',
#   'gardenias_00069.jpg',
#   'gardenias_00070.jpg',
#   'gardenias_00072.jpg',
#   'gardenias_00083.jpg'],
#  29: ['bougainvillea_00037.jpg',
#   'bougainvillea_00050.jpg',
#   'bougainvillea_00056.jpg',
#   'garden_roses_00067.jpg',
#   'garden_roses_00078.jpg'],
#  169: ['bougainvillea_00039.jpg',
#   'bougainvillea_00052.jpg',
#   'gardenias_00027.jpg',
#   'gardenias_00037.jpg',
#   'hibiscus_00011.jpg',
#   'hibiscus_00016.jpg',
#   'hibiscus_00025.jpg',
#   'hibiscus_00041.jpg',
#   'hibiscus_00050.jpg',
#   'hibiscus_00058.jpg',
#   'hibiscus_00062.jpg'],
#  13: ['bougainvillea_00061.jpg'],
#  52: ['bougainvillea_00063.jpg', 'hydrangeas_00027.jpg'],
#  161: ['daisies_00002.jpg',
#   'daisies_00005.jpg',
#   'daisies_00008.jpg',
#   'daisies_00023.jpg',
#   'daisies_00030.jpg',
#   'daisies_00081.jpg',
#   'garden_roses_00012.jpg',
#   'garden_roses_00085.jpg',
#   'gardenias_00041.jpg',
#   'gardenias_00047.jpg'],
#  165: ['daisies_00004.jpg',
#   'daisies_00012.jpg',
#   'daisies_00028.jpg',
#   'daisies_00034.jpg',
#   'daisies_00036.jpg',
#   'daisies_00051.jpg',
#   'daisies_00053.jpg',
#   'daisies_00057.jpg',
#   'daisies_00065.jpg',
#   'hydrangeas_00008.jpg'],
#  177: ['daisies_00022.jpg',
#   'daisies_00035.jpg',
#   'daisies_00056.jpg',
#   'daisies_00062.jpg',
#   'daisies_00063.jpg',
#   'daisies_00075.jpg',
#   'daisies_00084.jpg',
#   'daisies_00086.jpg',
#   'garden_roses_00015.jpg',
#   'garden_roses_00038.jpg',
#   'garden_roses_00040.jpg',
#   'garden_roses_00050.jpg',
#   'garden_roses_00052.jpg',
#   'garden_roses_00057.jpg',
#   'garden_roses_00065.jpg',
#   'garden_roses_00077.jpg',
#   'garden_roses_00084.jpg',
#   'gardenias_00039.jpg',
#   'gardenias_00045.jpg',
#   'gardenias_00081.jpg',
#   'hydrangeas_00012.jpg'],
#  185: ['daisies_00038.jpg',
#   'daisies_00088.jpg',
#   'garden_roses_00008.jpg',
#   'garden_roses_00017.jpg',
#   'garden_roses_00086.jpg',
#   'gardenias_00005.jpg',
#   'gardenias_00006.jpg',
#   'gardenias_00008.jpg',
#   'gardenias_00010.jpg',
#   'gardenias_00012.jpg',
#   'gardenias_00014.jpg',
#   'gardenias_00016.jpg',
#   'gardenias_00018.jpg',
#   'gardenias_00019.jpg',
#   'gardenias_00029.jpg',
#   'gardenias_00038.jpg',
#   'gardenias_00043.jpg',
#   'gardenias_00049.jpg',
#   'gardenias_00051.jpg',
#   'gardenias_00056.jpg',
#   'gardenias_00058.jpg',
#   'gardenias_00063.jpg',
#   'gardenias_00065.jpg',
#   'gardenias_00068.jpg',
#   'gardenias_00082.jpg',
#   'gardenias_00085.jpg',
#   'gardenias_00086.jpg',
#   'hibiscus_00004.jpg',
#   'hibiscus_00010.jpg',
#   'hibiscus_00012.jpg',
#   'hibiscus_00019.jpg',
#   'hibiscus_00021.jpg',
#   'hibiscus_00028.jpg',
#   'hibiscus_00030.jpg',
#   'hibiscus_00031.jpg',
#   'hibiscus_00032.jpg',
#   'hibiscus_00034.jpg',
#   'hibiscus_00036.jpg',
#   'hibiscus_00045.jpg',
#   'hibiscus_00055.jpg',
#   'hibiscus_00059.jpg',
#   'hibiscus_00060.jpg',
#   'hibiscus_00070.jpg',
#   'hibiscus_00071.jpg',
#   'hibiscus_00075.jpg',
#   'hibiscus_00076.jpg',
#   'hibiscus_00079.jpg',
#   'hibiscus_00083.jpg',
#   'hydrangeas_00002.jpg',
#   'hydrangeas_00018.jpg'],
#  188: ['daisies_00059.jpg', 'daisies_00064.jpg', 'daisies_00071.jpg'],
#  172: ['daisies_00061.jpg'],
#  149: ['daisies_00079.jpg'],
#  57: ['garden_roses_00003.jpg'],
#  221: ['garden_roses_00014.jpg'],
#  183: ['garden_roses_00019.jpg'],
#  249: ['garden_roses_00024.jpg'],
#  49: ['garden_roses_00027.jpg', 'garden_roses_00080.jpg'],
#  145: ['garden_roses_00042.jpg',
#   'garden_roses_00058.jpg',
#   'garden_roses_00062.jpg'],
#  179: ['garden_roses_00071.jpg'],
#  225: ['garden_roses_00087.jpg'],
#  153: ['gardenias_00030.jpg',
#   'gardenias_00052.jpg',
#   'hibiscus_00044.jpg',
#   'hibiscus_00053.jpg'],
#  63: ['gardenias_00034.jpg'],
#  187: ['gardenias_00057.jpg'],
#  237: ['hibiscus_00064.jpg'],
#  233: ['hibiscus_00077.jpg']}

# %%
def query_image2(file_path, tables):
    
    image = ResnetPreprocess(file_path)
    feature_image = model.predict(tf.expand_dims(image, axis=0))
    
    similar_results = {}
    added_images = set()
    
    for i,table in enumerate(tables):
        random_projections = create_projections(2048,8,i)
        bucket = hash_func(feature_image, random_projections)[0]
        
    
        if bucket in table:
            for img in table[bucket]:
                if img not in added_images:
                    if bucket in similar_results:
                        similar_results[bucket].append(img)
                    else:
                        similar_results[bucket] = [img]
                    added_images.add(img)
    return added_images,feature_image

# %%
similar_images,feature_query =query_image2("FLOWERS/daisies_00002.jpg",tables)
# Out:
# 1/1 [==============================] - 0s 214ms/step

# %%
similar_images
# Out:
# {'Flower.jpg',
#  'Flower2.jpg',
#  'bougainvillea_00003.jpg',
#  'bougainvillea_00005.jpg',
#  'bougainvillea_00009.jpg',
#  'bougainvillea_00014.jpg',
#  'bougainvillea_00015.jpg',
#  'bougainvillea_00017.jpg',
#  'bougainvillea_00021.jpg',
#  'bougainvillea_00028.jpg',
#  'bougainvillea_00034.jpg',
#  'bougainvillea_00039.jpg',
#  'bougainvillea_00047.jpg',
#  'bougainvillea_00052.jpg',
#  'bougainvillea_00059.jpg',
#  'bougainvillea_00063.jpg',
#  'bougainvillea_00069.jpg',
#  'bougainvillea_00073.jpg',
#  'bougainvillea_00075.jpg',
#  'bougainvillea_00078.jpg',
#  'daisies_00002.jpg',
#  'daisies_00003.jpg',
#  'daisies_00004.jpg',
#  'daisies_00005.jpg',
#  'daisies_00006.jpg',
#  'daisies_00007.jpg',
#  'daisies_00008.jpg',
#  'daisies_00009.jpg',
#  'daisies_00010.jpg',
#  'daisies_00011.jpg',
#  'daisies_00012.jpg',
#  'daisies_00013.jpg',
#  'daisies_00015.jpg',
#  'daisies_00016.jpg',
#  'daisies_00017.jpg',
#  'daisies_00019.jpg',
#  'daisies_00021.jpg',
#  'daisies_00022.jpg',
#  'daisies_00023.jpg',
#  'daisies_00024.jpg',
#  'daisies_00025.jpg',
#  'daisies_00026.jpg',
#  'daisies_00027.jpg',
#  'daisies_00028.jpg',
#  'daisies_00029.jpg',
#  'daisies_00030.jpg',
#  'daisies_00032.jpg',
#  'daisies_00033.jpg',
#  'daisies_00034.jpg',
#  'daisies_00035.jpg',
#  'daisies_00036.jpg',
#  'daisies_00037.jpg',
#  'daisies_00038.jpg',
#  'daisies_00039.jpg',
#  'daisies_00041.jpg',
#  'daisies_00043.jpg',
#  'daisies_00044.jpg',
#  'daisies_00046.jpg',
#  'daisies_00047.jpg',
#  'daisies_00051.jpg',
#  'daisies_00052.jpg',
#  'daisies_00053.jpg',
#  'daisies_00054.jpg',
#  'daisies_00056.jpg',
#  'daisies_00057.jpg',
#  'daisies_00059.jpg',
#  'daisies_00062.jpg',
#  'daisies_00063.jpg',
#  'daisies_00064.jpg',
#  'daisies_00065.jpg',
#  'daisies_00066.jpg',
#  'daisies_00070.jpg',
#  'daisies_00071.jpg',
#  'daisies_00072.jpg',
#  'daisies_00073.jpg',
#  'daisies_00074.jpg',
#  'daisies_00075.jpg',
#  'daisies_00076.jpg',
#  'daisies_00077.jpg',
#  'daisies_00078.jpg',
#  'daisies_00079.jpg',
#  'daisies_00080.jpg',
#  'daisies_00081.jpg',
#  'daisies_00082.jpg',
#  'daisies_00084.jpg',
#  'daisies_00085.jpg',
#  'daisies_00086.jpg',
#  'daisies_00087.jpg',
#  'daisies_00088.jpg',
#  'garden_roses_00012.jpg',
#  'garden_roses_00013.jpg',
#  'garden_roses_00014.jpg',
#  'garden_roses_00017.jpg',
#  'garden_roses_00018.jpg',
#  'garden_roses_00019.jpg',
#  'garden_roses_00039.jpg',
#  'garden_roses_00040.jpg',
#  'garden_roses_00041.jpg',
#  'garden_roses_00049.jpg',
#  'garden_roses_00050.jpg',
#  'garden_roses_00051.jpg',
#  'garden_roses_00052.jpg',
#  'garden_roses_00053.jpg',
#  'garden_roses_00055.jpg',
#  'garden_roses_00057.jpg',
#  'garden_roses_00058.jpg',
#  'garden_roses_00065.jpg',
#  'garden_roses_00075.jpg',
#  'garden_roses_00079.jpg',
#  'garden_roses_00080.jpg',
#  'garden_roses_00085.jpg',
#  'gardenias_00003.jpg',
#  'gardenias_00004.jpg',
#  'gardenias_00005.jpg',
#  'gardenias_00006.jpg',
#  'gardenias_00007.jpg',
#  'gardenias_00009.jpg',
#  'gardenias_00010.jpg',
#  'gardenias_00011.jpg',
#  'gardenias_00012.jpg',
#  'gardenias_00013.jpg',
#  'gardenias_00018.jpg',
#  'gardenias_00019.jpg',
#  'gardenias_00021.jpg',
#  'gardenias_00022.jpg',
#  'gardenias_00026.jpg',
#  'gardenias_00027.jpg',
#  'gardenias_00029.jpg',
#  'gardenias_00035.jpg',
#  'gardenias_00037.jpg',
#  'gardenias_00038.jpg',
#  'gardenias_00039.jpg',
#  'gardenias_00041.jpg',
#  'gardenias_00045.jpg',
#  'gardenias_00047.jpg',
#  'gardenias_00051.jpg',
#  'gardenias_00052.jpg',
#  'gardenias_00054.jpg',
#  'gardenias_00055.jpg',
#  'gardenias_00058.jpg',
#  'gardenias_00059.jpg',
#  'gardenias_00060.jpg',
#  'gardenias_00063.jpg',
#  'gardenias_00064.jpg',
#  'gardenias_00065.jpg',
#  'gardenias_00067.jpg',
#  'gardenias_00068.jpg',
#  'gardenias_00069.jpg',
#  'gardenias_00072.jpg',
#  'gardenias_00073.jpg',
#  'gardenias_00075.jpg',
#  'gardenias_00076.jpg',
#  'gardenias_00077.jpg',
#  'gardenias_00079.jpg',
#  'gardenias_00080.jpg',
#  'gardenias_00081.jpg',
#  'gardenias_00083.jpg',
#  'gardenias_00084.jpg',
#  'gardenias_00085.jpg',
#  'gardenias_00086.jpg',
#  'hibiscus_00002.jpg',
#  'hibiscus_00007.jpg',
#  'hibiscus_00011.jpg',
#  'hibiscus_00019.jpg',
#  'hibiscus_00021.jpg',
#  'hibiscus_00031.jpg',
#  'hibiscus_00040.jpg',
#  'hibiscus_00041.jpg',
#  'hibiscus_00049.jpg',
#  'hibiscus_00050.jpg',
#  'hibiscus_00058.jpg',
#  'hibiscus_00065.jpg',
#  'hibiscus_00074.jpg',
#  'hibiscus_00076.jpg',
#  'hibiscus_00081.jpg',
#  'hibiscus_00082.jpg',
#  'hydrangeas_00002.jpg',
#  'hydrangeas_00004.jpg',
#  'hydrangeas_00005.jpg',
#  'hydrangeas_00006.jpg',
#  'hydrangeas_00008.jpg',
#  'hydrangeas_00009.jpg',
#  'hydrangeas_00010.jpg',
#  'hydrangeas_00016.jpg',
#  'hydrangeas_00017.jpg',
#  'hydrangeas_00020.jpg',
#  'hydrangeas_00021.jpg',
#  'hydrangeas_00022.jpg'}

# %% [markdown]
# ## Trying all together

# %%
"bougainvillea_00002.jpg" in labels
# Out:
# True

# %%
for label in similar_images:
    print(features[labels.index(label)])
    break
# Out:
# [8.790187   0.         0.18383636 ... 0.         0.         0.27366945]

# %%
def Cosine_similarity(img1,img2):
    dot_product = np.dot(img1,img2.T)
    img1_norm = np.linalg.norm(img1)
    img2_norm = np.linalg.norm(img2)
    return (dot_product/(img1_norm*img2_norm))

# %%
def ANN(similar_images, QueryFeature, topn):
    similarities = []
    
    QueryFeature = QueryFeature.reshape(1,-1)
    
    for image in similar_images:
        ff = features[labels.index(image)]
        ff_2d = ff.reshape(1,-1)
        
        similarity = Cosine_similarity(ff_2d,QueryFeature)
        similarities.append((image , similarity))
    
    similarities.sort(reverse=True,key=lambda x:x[1])
    top_similar_images = [(image_label , simil*100) for image_label,simil in similarities[:topn]]
    return top_similar_images

# %%
daises = ANN(similar_images,feature_query,15)

# %%
daises
# Out:
# [('daisies_00002.jpg', array([[99.99999]], dtype=float32)),
#  ('daisies_00005.jpg', array([[92.72953]], dtype=float32)),
#  ('daisies_00003.jpg', array([[90.66134]], dtype=float32)),
#  ('daisies_00051.jpg', array([[90.47122]], dtype=float32)),
#  ('daisies_00004.jpg', array([[88.64832]], dtype=float32)),
#  ('daisies_00054.jpg', array([[87.73297]], dtype=float32)),
#  ('daisies_00025.jpg', array([[87.69926]], dtype=float32)),
#  ('daisies_00028.jpg', array([[86.790695]], dtype=float32)),
#  ('daisies_00065.jpg', array([[85.67798]], dtype=float32)),
#  ('daisies_00027.jpg', array([[84.95759]], dtype=float32)),
#  ('daisies_00073.jpg', array([[84.62109]], dtype=float32)),
#  ('daisies_00034.jpg', array([[84.53584]], dtype=float32)),
#  ('daisies_00016.jpg', array([[84.35074]], dtype=float32)),
#  ('daisies_00009.jpg', array([[83.91857]], dtype=float32)),
#  ('daisies_00036.jpg', array([[83.56021]], dtype=float32))]

# %%
import matplotlib.pyplot as plt
import cv2
r = cv2.imread("FLOWERS/bougainvillea_00017.jpg")
l = cv2.imread("FLOWERS/Flower2.jpg")
plt.imshow(r)

# %%
plt.imshow(l)

# %%
create_projections(2048,4,1)
# Out:
# array([[ 1.62434536, -0.61175641, -0.52817175, ..., -0.08339327,
#          0.01175551,  1.20809946],
#        [-1.82921963,  0.23443672, -0.12071047, ..., -1.47883394,
#         -0.49290457,  0.79494725],
#        [-1.09221351,  2.08651464,  1.316653  , ..., -1.95176055,
#          0.21272915,  0.10822446],
#        [ 0.13130697, -1.36381382,  0.23921477, ..., -0.61378208,
#          1.3543076 ,  0.5320339 ]])

# %%
def query_image(file_path,neighbours,tables):
    
    image = ResnetPreprocess(file_path)
    feature_image = model.predict(tf.expand_dims(image, axis=0))
    
    
    random_projections = create_projections(2048,8)
    bucket = hash_func(feature_image,random_projections)
    bucket = bucket[0]
    
    print(bucket)
    similar_results = {}
    
    
    for i,table in enumerate(tables):
        if bucket in table:
            if bucket in similar_results:
                similar_results[bucket].extend(table[bucket])
            else:
                similar_results[bucket] = table[bucket]
        
    return similar_results
